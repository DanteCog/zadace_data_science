# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Load the cleaned dataset from the last exercise. If you haven't saved the dataset, rerun the exercise and save the final dataset.

# %%
studenti = pd.read_csv("studenti_cleaned_1.csv")
studenti
# Out:
#        EthnicGroup  ParentEduc  TestPrep  ParentMaritalStatus  PracticeSport  \
# 0                2           1         1                    1              1
# 1                2           5         1                    1              2
# 2                1           3         1                    2              2
# 3                0           0         1                    1              0
# 4                2           5         1                    1              2
# ...            ...         ...       ...                  ...            ...
# 29112            3           2         1                    2              2
# 29113            4           2         1                    2              1
# 29114            2           2         0                    1              2
# 29115            3           0         0                    1              1
# 29116            1           5         1                    1              0
#
# ...

# %% [markdown]
# 2. a) Find the mean, median and average scores in mathematics, reading and writing. <br>
#    b) Find the mean, median and average scores for males and females.<br>
#    c) What is the coefficient of variation of the scores? <br>

# %%
a = studenti['MathScore'].mean()
b = studenti['ReadingScore'].mean()
c = studenti['WritingScore'].mean()
a_a = studenti['MathScore'].median()
b_b = studenti['ReadingScore'].median()
c_c = studenti['WritingScore'].median()
print(a,b,c)
print(a_a, b_b, c_c)

a_fem = studenti.loc[studenti.loc[:,'Gender_female'] == 1, 'MathScore'].mean()
a_men = studenti.loc[studenti.loc[:,'Gender_female'] == 0, 'MathScore'].mean()
b_fem = studenti.loc[studenti.loc[:,'Gender_female'] == 1, 'ReadingScore'].mean()
b_men = studenti.loc[studenti.loc[:,'Gender_female'] == 0, 'ReadingScore'].mean()
c_fem = studenti.loc[studenti.loc[:,'Gender_female'] == 1, 'WritingScore'].mean()
c_men = studenti.loc[studenti.loc[:,'Gender_female'] == 0, 'WritingScore'].mean()
med_a_fem = studenti.loc[studenti.loc[:,'Gender_female'] == 1, 'MathScore'].median()
med_a_men = studenti.loc[studenti.loc[:,'Gender_female'] == 0, 'MathScore'].median()
med_b_fem = studenti.loc[studenti.loc[:,'Gender_female'] == 1, 'ReadingScore'].median()
med_b_men = studenti.loc[studenti.loc[:,'Gender_female'] == 0, 'ReadingScore'].median()
med_c_fem = studenti.loc[studenti.loc[:,'Gender_female'] == 1, 'WritingScore'].median()
med_c_men = studenti.loc[studenti.loc[:,'Gender_female'] == 0, 'WritingScore'].median()

std_a = studenti['MathScore'].std() / studenti.MathScore.mean()
print(a_fem)
print(a_men)
print(med_b_men)
print(b_men)
print(std_a)
#(0, 0)\t1.0,
# Out:
# 66.55994779681973 69.39008139574818 68.42933681354535
# 67.0 70.0 69.0
# 64.11941926249062
# 69.03848816281324
# 66.0
# 65.82465734459366
# 0.2305328273670254

# %% [markdown]
# 3. a) Use a statistical test to test the hypothesis:<br>
# H0: the mean mathematical scores of females and males are equal.

# %%
from scipy import stats as st
žene =  studenti.loc[studenti.loc[:,'Gender_female'] == 1, 'MathScore']
muškarci =  studenti.loc[studenti.loc[:,'Gender_female'] == 0, 'MathScore']
st.ttest_1samp(žene, 69.03848816281324)
# Out:
# TtestResult(statistic=-39.215695887253865, pvalue=0.0, df=14670)

# %% [markdown]
# 4. a) Use a statistical test to test the hypothesis:<br>
#    H0 Gender did not affect the writing scores.<br>
#    H1 Gender affected the writing score.<br>

# %%
muški_scores = studenti[studenti['Gender_female'] == 0]['WritingScore']
ženski_scores = studenti[studenti['Gender_female'] == 1]['WritingScore']

ttest_ind(muški_scores, ženski_scores)
alpha = 0.05
if p_value < alpha:
    print("Gender affects writing scores.")
else:
    print("Gender does not affect writing scores.")
# Out:
# Gender does not affect writing scores.

# %% [markdown]
# 5. a) Statisticaly test the distribuitions of female and male scores across the three scores columns.<br>
# b) Plot the distributions for each of the separate scores in both genders. <br>

# %%
from scipy.stats import ks_2samp

muški_math_scores = studenti[studenti['Gender_female'] == 0]['MathScore']
žene_math_scores = studenti[studenti['Gender_female'] == 1]['MathScore']

muški_reading_scores = studenti[studenti['Gender_female'] == 0]['ReadingScore']
žene_reading_scores = studenti[studenti['Gender_female'] == 1]['ReadingScore']

muški_writing_scores = studenti[studenti['Gender_female'] == 0]['WritingScore']
žene_writing_scores = studenti[studenti['Gender_female'] == 1]['WritingScore']

a = ks_2samp(muški_math_scores, žene_math_scores)
b = ks_2samp(muški_reading_scores, žene_reading_scores)
c = ks_2samp(muški_writing_scores, žene_writing_scores)

print(a)
print(b)
print(c)

plt.figure(figsize=(12, 8))

plt.subplot(3, 1, 1)
sns.histplot(data=studenti, x='MathScore', hue='Gender_female', kde=True)
plt.title('Math Scores Distribution')

plt.subplot(3, 1, 2)
sns.histplot(data=studenti, x='ReadingScore', hue='Gender_female', kde=True)
plt.title('Reading Scores Distribution')

plt.subplot(3, 1, 3)
sns.histplot(data=studenti, x='WritingScore', hue='Gender_female', kde=True)
plt.title('Writing Scores Distribution')
# Out:
# KstestResult(statistic=0.1287474379328834, pvalue=1.1935280263689127e-105, statistic_location=65, statistic_sign=-1)
# KstestResult(statistic=0.19177469714080392, pvalue=6.152041663039829e-235, statistic_location=69, statistic_sign=1)
# KstestResult(statistic=0.23284192974349305, pvalue=0.0, statistic_location=70, statistic_sign=1)
# Text(0.5, 1.0, 'Writing Scores Distribution')
